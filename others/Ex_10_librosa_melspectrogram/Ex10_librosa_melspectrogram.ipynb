# %%
from google.colab import drive
drive.mount('/content/drive/',force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
import os
dirpath="/content/drive/MyDrive/Colab Notebooks"
# dirpath="/content/drive/MyDrive/Suganyateam/HHT/Data_1.5mm_30kv"
os.chdir(dirpath)

# %%
from IPython.display import Audio
wn = Audio('/content/drive/MyDrive/Colab Notebooks/hari.mp3', autoplay=True)
display(wn)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio
wn = Audio('/content/drive/MyDrive/Colab Notebooks/priya.mp3', autoplay=True)
display(wn)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
import matplotlib.pyplot as plt
data1, sr1 = librosa.load('hari.mp3', sr=None)
data2, sr2 = librosa.load('priya.mp3', sr=None)

# %%
import numpy as np
plt.plot(data1)
plt.show()
plt.plot(data2)

# %%
from numpy.fft import fft, ifft
sr=90

X = fft(data1)
N = len(X)
n = np.arange(N)
T = N/sr
freq = n/T 

X1 = fft(data2)
N1 = len(X1)
n1 = np.arange(N1)
T1 = N1/sr
freq1 = n1/T1 

plt.figure(figsize = (12, 6))
plt.subplot(121)

plt.stem(freq, np.abs(X), 'b', \
         markerfmt=" ", basefmt="-b")
plt.xlabel('Freq (Hz)')
plt.ylabel('Hari-FFT Amplitude |X(freq)|')
plt.xlim(0, 10)
plt.subplot(122)

plt.stem(freq1, np.abs(X1), 'b', \
         markerfmt=" ", basefmt="-b")
plt.xlabel('Freq (Hz)')
plt.ylabel('Priya-FFT Amplitude |X(freq)|')
plt.xlim(0, 10)
# Out:
# (0.0, 10.0)

# %%
import numpy as np

import librosa.display
plt.figure(figsize = (12, 6))
plt.subplot(121)
plt.specgram(data1, Fs=6)
plt.subplot(122)
plt.specgram(data2, Fs=6)
# Out:
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_axes.py:7628: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)
# (array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          5.34994336e-07, 7.51261269e-07, 1.07542576e-06],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          1.45759793e-05, 1.59513593e-05, 2.63295840e-06],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          1.39681063e-05, 4.54302695e-05, 3.12362939e-06],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          2.61933976e-15, 4.90338260e-16, 3.67370357e-16],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          1.48712837e-15, 5.63993409e-17, 4.82647119e-17],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          5.70778757e-16, 1.04279717e-17, 2.03085584e-17]]),
#  array([0.       , 0.0234375, 0.046875 , 0.0703125, 0.09375  , 0.1171875,
# ...

# %%
hop_length = 512
n_fft = 2048
S=librosa.feature.melspectrogram(data1, sr=22050, S=None, n_fft=2048, hop_length=512, win_length=None, window='hann', center=True, pad_mode='constant', power=2.0)
# D = np.abs(librosa.stft(data1))**2
# S = librosa.feature.melspectrogram(S=D, sr=sr)
S_dB = librosa.power_to_db(S, ref=np.max)
fig, ax = plt.subplots()
img = librosa.display.specshow(S_dB, x_axis='time', y_axis='mel', sr=sr,fmax=8000, ax=ax)
fig.colorbar(img, ax=ax, format='%+2.0f dB')
ax.set(title='Mel-frequency spectrogram')

# %%
hop_length = 512
n_fft = 2048
S=librosa.feature.melspectrogram(data2, sr=22050, S=None, n_fft=2048, hop_length=512, win_length=None, window='hann', center=True, pad_mode='constant', power=2.0)
# D = np.abs(librosa.stft(data2))**2
# S = librosa.feature.melspectrogram(S=D, sr=sr)
S_dB = librosa.power_to_db(S, ref=np.max)
fig, ax = plt.subplots()
img = librosa.display.specshow(S_dB, x_axis='time', y_axis='mel', sr=sr,fmax=8000, ax=ax)
fig.colorbar(img, ax=ax, format='%+2.0f dB')
ax.set(title='Mel-frequency spectrogram')
# Out:
# [Text(0.5, 1.0, 'Mel-frequency spectrogram')]
